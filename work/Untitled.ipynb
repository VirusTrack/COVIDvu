# %%
import pandas as pd

# %%
from covidvu.utils import autoReloadCode; autoReloadCode()

# %%
from covidvu.vujson import JH_CSSE_FILE_CONFIRMED,STATE_CODES_PATH,US_REGIONS,makeUSRegionsVerbose,_isCounty
from covidvu.vujson import splitCSSEData,splitCSSEDataByParsingBoundary
from covidvu.vujson import PARSING_MODE_BOUNDARY_1,_getCounties_mode1
from covidvu.vujson import allUSCases, allCases

# %%
sourceFileName = JH_CSSE_FILE_CONFIRMED

# %%
casesGlobalCollection = [0, 0]
casesUSStatesCollection = [0, 0]
casesUSRegionsCollection = [0, 0]
casesUSCountiesCollection = [0, 0]
casesBoatsCollection = [0, 0]

cases = pd.read_csv(sourceFileName)
cases = splitCSSEDataByParsingBoundary(cases)

# Parsing type 1
casesUS,  casesUSRegions = allUSCases(cases[0])
casesUSCounties = _getCounties_mode1(cases[0])

casesGlobalCollection[0] = allCases(cases[0])
casesUSStatesCollection[0] = casesUS
casesUSRegionsCollection[0] = casesUSRegions
casesUSCountiesCollection[0] = casesUSCounties
#casesBoatsCollection[0] =

# Parsing type 2
casesGlobal2, casesUSRegions2, casesUSStates2, casesUSCounties2, casesBoats2 = splitCSSEData(cases[1])

casesGlobalCollection[1] = casesGlobal2
casesUSRegionsCollection[1] = casesUSRegions2
casesUSStatesCollection[1] = casesUSStates2
casesUSCountiesCollection[1] = casesUSCounties2

# %%
pd.concat(casesUSRegionsCollection).tail()
# Out:
#             !Total US  Diamond Princess  Midwest  Northeast  South  \
# 2020-03-07        402              45.0        9         93     30
# 2020-03-08        518              45.0       13        147     42
# 2020-03-09        583              45.0       20        184     57
# 2020-03-10       1784               NaN       40        302     90
# 2020-03-11       2428               NaN       81        368    134
#
#             Unassigned  West
# 2020-03-07          21   204
# 2020-03-08          23   248
# 2020-03-09          23   254
# 2020-03-10         897   455
# 2020-03-11        1224   621

# %%
casesUSStatesCollection[0].tail()
# Out:
#             !Total US  Alabama  Alaska  Arizona  Arkansas  California  \
# 2020-03-05        217        0       0        1         0          51
# 2020-03-06        262        0       0        2         0          59
# 2020-03-07        402        0       0        4         0          81
# 2020-03-08        518        0       0        4         0          95
# 2020-03-09        583        0       0        4         0         101
#
#             Colorado  Connecticut  Delaware  Florida  ...  Texas  Unassigned  \
# 2020-03-05         0            0         0        3  ...      3          45
# 2020-03-06         3            0         0        3  ...      4          45
# 2020-03-07         7            0         0        7  ...      8          66
# 2020-03-08         7            0         0       10  ...     11          68
# 2020-03-09         7            0         0       13  ...     13          68
#
#             Utah  Vermont  Virginia  Washington  Washington D.C.  \
# 2020-03-05     0        0         0          70                0
# 2020-03-06     0        0         0          78                0
# 2020-03-07     1        0         0         102                0
# 2020-03-08     1        1         2         122                0
# 2020-03-09     1        1         2         122                0
#
#             West Virginia  Wisconsin  Wyoming
# 2020-03-05              0          0        0
# 2020-03-06              0          0        0
# 2020-03-07              0          0        0
# 2020-03-08              0          0        0
# 2020-03-09              0          0        0
#
# [5 rows x 53 columns]

# %%
casesUSStatesCollection[1].tail()
# Out:
#             Unassigned  South  West  West  South  West  West  Northeast  \
# 2020-03-10         892      0     0     6      0   144    15          2
# 2020-03-11        1214      0     0     9      1   177    34          3
#
#             South  Unassigned  ...  South  West  Northeast  South  West  \
# 2020-03-10      0           5  ...     13     2          1      7   267
# 2020-03-11      1          10  ...     21     3          1      9   366
#
#             South  Unassigned  South  Midwest  West
# 2020-03-10      0           0      0        3     0
# 2020-03-11      0           0      0        6     0
#
# [2 rows x 54 columns]

# %%
casesGlobal = pd.concat(casesGlobalCollection)
casesUSRegions = pd.concat(casesUSRegionsCollection)
casesUSStates = pd.concat(casesUSStatesCollection)
casesUSCounties = pd.concat(casesUSCountiesCollection)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-0ccf1b372931> in <module>
#       1 casesGlobal = pd.concat(casesGlobalCollection)
#       2 casesUSRegions = pd.concat(casesUSRegionsCollection)
# ----> 3 casesUSStates = pd.concat(casesUSStatesCollection)
#       4 casesUSCounties = pd.concat(casesUSCountiesCollection)
#
# c:\users\jarya\dropbox\projects\covidvu\work\env\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# c:\users\jarya\dropbox\projects\covidvu\work\env\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     494                 mgrs_indexers.append((obj._data, indexers))
#     495
# --> 496             new_data = concatenate_block_managers(
#     497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#
# c:\users\jarya\dropbox\projects\covidvu\work\env\lib\site-packages\pandas\core\internals\managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2014                 values = values.view()
#    2015             b = b.make_block_same_class(values, placement=placement)
# -> 2016         elif is_uniform_join_units(join_units):
#    2017             b = join_units[0].block.concat_same_type(
#    2018                 [ju.block for ju in join_units], placement=placement
#
# c:\users\jarya\dropbox\projects\covidvu\work\env\lib\site-packages\pandas\core\internals\concat.py in is_uniform_join_units(join_units)
#     386         # no blocks that would get missing values (can lead to type upcasts)
#     387         # unless we're an extension dtype.
# --> 388         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     389         and
#     390         # no blocks with indexers (as then the dimensions do not fit)
#
# c:\users\jarya\dropbox\projects\covidvu\work\env\lib\site-packages\pandas\core\internals\concat.py in <genexpr>(.0)
#     386         # no blocks that would get missing values (can lead to type upcasts)
#     387         # unless we're an extension dtype.
# --> 388         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     389         and
#     390         # no blocks with indexers (as then the dimensions do not fit)
#
# AttributeError: 'NoneType' object has no attribute 'is_extension'

# %%
a, b = casesGlobalCollection

# %%
df = cases[0]

